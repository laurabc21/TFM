# %% [markdown]
# #Spanish

# %%
# !gdown 1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# To: /content/dataset_ES.csv
# 100% 98.1k/98.1k [00:00<00:00, 34.2MB/s]

# %%
import pandas as pd

# %%
df_spanish = pd.read_csv('/content/dataset_ES.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1f5tojMnxC1OfMEFeA-a1X4xdMUU4zSy_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1f5tojMnxC1OfMEFeA-a1X4xdMUU4zSy_
# To: /content/output_fewshot1_ES.jsonl
# 100% 198k/198k [00:00<00:00, 63.6MB/s]

# %%
import json

# %%
df_output_es = pd.read_json('/content/output_fewshot1_ES.jsonl', lines=True)

df_output_es.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_spanish['translation'] = df_output_es['translation']

# %%
import re
import pandas as pd

def extract_translation_or_keep(text):
    if pd.isna(text):
        return text  # keep NaN

    match = re.search(r'Translation:\s*(.*)', text, flags=re.DOTALL)

    if match:
        return match.group(1).strip()

    return text  # if no "Traducción:", keep full original output

df_spanish['translation'] = df_output_es['translation'].apply(extract_translation_or_keep)

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_spanish.to_excel('TranslateGemma_ES_fewhot1.xlsx', index=False)

# %% [markdown]
# #Catalan

# %%
# !gdown 12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# To: /content/dataset_CAT.csv
# 100% 118k/118k [00:00<00:00, 21.3MB/s]

# %%
import pandas as pd

# %%
df_catalan = pd.read_csv('/content/dataset_CAT.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 13bqLYEd-6E9zHK91etrdT6gX2_vLLcc7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13bqLYEd-6E9zHK91etrdT6gX2_vLLcc7
# To: /content/output_fewshot1_CAT.jsonl
# 100% 233k/233k [00:00<00:00, 93.5MB/s]

# %%
import json

# %%
df_output_ca = pd.read_json('output_fewshot1_CAT.jsonl', lines=True)

df_output_ca.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_catalan['translation'] = df_output_ca['translation']

# %%
import re
import pandas as pd

def extract_translation(text):
    if pd.isna(text):
        return text  # keep NaN as is

    match = re.search(r'Traducción:\s*(.*)', text, flags=re.DOTALL)

    if match:
        return match.group(1).strip()

    return text  # keep original if no "Traducción:" found

df_catalan["translation"] = df_catalan["translation"].apply(extract_translation)

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_catalan.to_excel('TranslateGemma_CAT_fewshot1.xlsx', index=False)
