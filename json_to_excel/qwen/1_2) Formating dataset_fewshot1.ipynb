# %% [markdown]
# #Spanish

# %%
# !gdown 1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# To: /content/dataset_ES.csv
# 100% 98.1k/98.1k [00:00<00:00, 9.93MB/s]

# %%
import pandas as pd

# %%
df_spanish = pd.read_csv('/content/dataset_ES.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1aMXPWR3D4Sh9z1YaHMlisG76uOWSCJ57
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aMXPWR3D4Sh9z1YaHMlisG76uOWSCJ57
# To: /content/output_fewshot1_ES_qwen
# 100% 212k/212k [00:00<00:00, 71.1MB/s]

# %%
import json

# %%
df_output_es = pd.read_json('/content/output_fewshot1_ES_qwen', lines=True)

df_output_es.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_spanish['translation'] = df_output_es['translation']

# %%
import re
import pandas as pd

def extract_section(text):
    if pd.isna(text):
        return text

    match = re.search(
        r"Here'?s the translation.*?:\s*(.*?)(?=\n\s*Later text:|$)",
        text,
        re.IGNORECASE | re.DOTALL
    )

    if match:
        return match.group(1).strip()

    return text.strip()


df_spanish['translation'] = df_output_es['translation'].apply(extract_section)

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_spanish.to_excel('Qwen_ES_fewshot1.xlsx', index=False)

# %% [markdown]
# #Catalan

# %%
# !gdown 12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# To: /content/dataset_CAT.csv
# 100% 118k/118k [00:00<00:00, 62.7MB/s]

# %%
import pandas as pd

# %%
df_catalan = pd.read_csv('/content/dataset_CAT.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1oHVZrb32B4hIwa1pVdAf75KRD6ucQbrC
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oHVZrb32B4hIwa1pVdAf75KRD6ucQbrC
# To: /content/output_fewshot1_CAT_qwen
# 100% 316k/316k [00:00<00:00, 87.2MB/s]

# %%
import json

# %%
df_output_ca = pd.read_json('/content/output_fewshot1_CAT_qwen', lines=True)

df_output_ca.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_catalan['translation'] = df_output_ca['translation']

# %%
import re
import pandas as pd

def extract_texto_a_traducir(text):
    if pd.isna(text):
        return text

    match = re.search(
        r"Texto a traducir:\s*(.*?)(?=\n\s*Texto posterior:|\n\s*Texto anterior:|$)",
        text,
        re.DOTALL | re.IGNORECASE
    )

    if match:
        return match.group(1).strip()

    return text.strip()


df_catalan['translation'] = df_output_ca['translation'].apply(extract_texto_a_traducir)

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_catalan.to_excel('Qwen_CAT_fewshot1.xlsx', index=False)
