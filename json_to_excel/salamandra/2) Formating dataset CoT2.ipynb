# %% [markdown]
# #Spanish

# %%
# !gdown 1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# To: /content/dataset_ES.csv
# 100% 98.1k/98.1k [00:00<00:00, 27.0MB/s]

# %%
import pandas as pd

# %%
df_spanish = pd.read_csv('/content/dataset_ES.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1Bq4Q4-nXBbJPbIhrV3CPSlEeRofX11NU
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Bq4Q4-nXBbJPbIhrV3CPSlEeRofX11NU
# To: /content/output_ES_CoT2_salam
# 100% 178k/178k [00:00<00:00, 83.5MB/s]

# %%
import json

# %%
df_output_es = pd.read_json('/content/output_ES_CoT2_salam', lines=True)

df_output_es.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_spanish['translation'] = df_output_es['translation']

# %%
import pandas as pd
import json

def extract_translation(text):
    if pd.isna(text):
        return text

    try:
        data = json.loads(text)
        return data.get("translation", "")
    except:
        return text

df_spanish['translation'] = df_output_es['translation'].apply(extract_translation)

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_spanish.to_excel('Salamandra_ES_CoT2.xlsx', index=False)

# %% [markdown]
# #Catalan

# %%
# !gdown 12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# To: /content/dataset_CAT.csv
# 100% 118k/118k [00:00<00:00, 99.4MB/s]

# %%
import pandas as pd

# %%
df_catalan = pd.read_csv('/content/dataset_CAT.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1YCvtVOknGOL0r8YrvPiBeag_DiWDDrSc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YCvtVOknGOL0r8YrvPiBeag_DiWDDrSc
# To: /content/output_CAT_CoT2_salam
# 100% 205k/205k [00:00<00:00, 86.0MB/s]

# %%
import json

# %%
df_output_ca = pd.read_json('output_CAT_CoT2_salam', lines=True)

df_output_ca.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'raw_cot_output',
#        'translation'],
#       dtype='object')

# %%
df_catalan['translation'] = df_output_ca['translation']

# %%
import re
import pandas as pd

def extract_texto_a_traducir(text):
    if pd.isna(text):
        return text

    match = re.search(
        r"Texto a traducir:\s*(.*?)(?=\n\s*Texto posterior:|\n\s*Texto anterior:|$)",
        text,
        re.DOTALL | re.IGNORECASE
    )

    if match:
        return match.group(1).strip()

    return text.strip()


df_catalan['translation'] = df_output_ca['translation'].apply(extract_texto_a_traducir)

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_catalan.to_excel('Salamandra_CAT_CoT2.xlsx', index=False)
