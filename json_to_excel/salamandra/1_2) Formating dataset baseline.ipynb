# %% [markdown]
# #Spanish

# %%
# !gdown 1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UHzDL2Yoh5Hr1pZ6jziC3YLsoI7Aszv3
# To: /content/dataset_ES.csv
# 100% 98.1k/98.1k [00:00<00:00, 61.8MB/s]

# %%
import pandas as pd

# %%
df_spanish = pd.read_csv('/content/dataset_ES.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1gsf0yKlvYhqOXc6Q0IEy9KUH5klV4Adk
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gsf0yKlvYhqOXc6Q0IEy9KUH5klV4Adk
# To: /content/output_ES_baseline_salamandra.jsonl
# 100% 179k/179k [00:00<00:00, 72.7MB/s]

# %%
import json

# %%
df_output_es = pd.read_json('/content/output_ES_baseline_salamandra.jsonl', lines=True)

df_output_es.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_spanish['translation'] = df_output_es['translation']

# %%
import pandas as pd
import json

def extract_translation(text):
    if pd.isna(text):
        return text

    try:
        data = json.loads(text)
        return data.get("translation", "")
    except:
        return text

df_spanish['translation'] = df_output_es['translation'].apply(extract_translation)

# %%
df_spanish.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_spanish.to_excel('Salamandra_ES_baseline.xlsx', index=False)

# %% [markdown]
# #Catalan

# %%
# !gdown 12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12f7BMvYcVNoKmYoM5KP2RTd4EbQZwizG
# To: /content/dataset_CAT.csv
# 100% 118k/118k [00:00<00:00, 73.0MB/s]

# %%
import pandas as pd

# %%
df_catalan = pd.read_csv('/content/dataset_CAT.csv', encoding='iso-8859-1', sep=None, engine='python')

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after'],
#       dtype='object')

# %%
# !gdown 1eI_1K8IvJFl0bRqdrFWN683IlpaOIAcq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eI_1K8IvJFl0bRqdrFWN683IlpaOIAcq
# To: /content/output_CAT_baseline_salamandra.jsonl
# 100% 217k/217k [00:00<00:00, 52.2MB/s]

# %%
import json

# %%
df_output_ca = pd.read_json('/content/output_CAT_baseline_salamandra.jsonl', lines=True)

df_output_ca.columns
# Out:
# Index(['text_previous', 'text_analyzed', 'text_after', 'translation'], dtype='object')

# %%
df_catalan['translation'] = df_output_ca['translation']

# %%
import re
import pandas as pd

def extract_texto_a_traducir(text):
    if pd.isna(text):
        return text

    match = re.search(
        r"Texto a traducir:\s*(.*?)(?=\n\s*Texto posterior:|\n\s*Texto anterior:|$)",
        text,
        re.DOTALL | re.IGNORECASE
    )

    if match:
        return match.group(1).strip()

    return text.strip()


df_catalan['translation'] = df_output_ca['translation'].apply(extract_texto_a_traducir)

# %%
df_catalan.columns
# Out:
# Index(['previous_id', 'text_previous', 'instance_analyzed_id', 'text_analyzed',
#        'after_id', 'text_after', 'translation'],
#       dtype='object')

# %%
# Convert to Excel
df_catalan.to_excel('Salam_CAT_baseline.xlsx', index=False)
